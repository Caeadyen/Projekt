# %%
# Viskoelastischer Würfel durch (0,1)*(0,1) links und rechts zusammengrdrückt

# %%
include("main.jl");

# %%
my = [1e20];

# %%
para= Parameter(1,1,20,20,[0; 0], 1, my , 0.25 , 3e10, 1e10, 0.01,-0.01,1,10);

# %%
data = builddata(para);

# %%
data = solvestoke(data,para);

# %%
plotgrid(data,para);
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
plotpressure(data,para);
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
tau=convert_tau(data,para);

# %%
plottau(data,para,tau,"tau2nd")
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)
# PyObject <matplotlib.colorbar.Colorbar object at 0x0000000041194320>

# %%
plottau(data,para,tau,"tauxx")
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)
# PyObject <matplotlib.colorbar.Colorbar object at 0x000000004148CAC8>

# %%
plottau(data,para,tau,"tauyy")
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)
# PyObject <matplotlib.colorbar.Colorbar object at 0x00000000424D54E0>

# %%
plottau(data,para,tau,"tauxy")
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)
# PyObject <matplotlib.colorbar.Colorbar object at 0x0000000042589C50>
