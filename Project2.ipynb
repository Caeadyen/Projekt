# %%
# Rechtecksgebiet mit horizontalen Schichten links und rechts zusammengrdrückt

# %%
include("main.jl");

# %%
my = [1e23; 1e20; 1e15; 1e17; 1e20] ;

# %%
# Ersten 2000 Jahre

# %%
para= Parameter(100,50,50,25,[0; -10], 5, my , 0.25 , 3e10, 1e10, 0.001,-0.001,10,2000);

# %%
data = builddata(para);

# %%
data = solvestoke(data,para);

# %%
plotgrid(data,para);
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
plotpressure(data,para);
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
tau=convert_tau(data,para);

# %%
plottau(data,para,tau,"tau2nd");
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
plottau(data,para,tau,"tauxx");
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
plottau(data,para,tau,"tauyy");
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
plottau(data,para,tau,"tauxy");
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
#Zweiten 2000 Jahre

# %%
data = solvestoke(data,para);

# %%
plotgrid(data,para);
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
plotpressure(data,para);
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
tau=convert_tau(data,para);

# %%
plottau(data,para,tau,"tau2nd");
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
plottau(data,para,tau,"tauxx");
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
plottau(data,para,tau,"tauyy");
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)

# %%
plottau(data,para,tau,"tauxy");
# Out:
# Figure(PyObject <Figure size 640x480 with 2 Axes>)
